# %%
import time_tracker
import table_plan

# %%
daily = table_plan.Table()

# %%
daily.table_data()
# Out:
# Enter the break_time_b_w_session in mins : 20
# Enter the total sessions required : 4
# Enter the any input select 0 for 4-12 or 1 for 5-12 or 2 for 6-12 or 3 for 12-9 : 1

# %%
daily.read_csv()
# Out:
#          date  total_time_available(h)  break_time_b_w_session(mins)  \
# 0  2023-06-05                       16                            20
#
#    total_work_time(h)  total_sessions morning_slots(12am - 11:59 am)  \
# 0           10.666667               4             5:00 am - 12:00 pm
#
#   afternoon_slots(12pm - 6pm) evening_slots(6pm-11:59pm)  tiffin_break(mins)  \
# 0          12:00 pm - 6:00 pm          6:00 pm - 9:00 pm                  30
#
#    lunch_break(mins)  snacks_break(mins)  dinner_break(mins)  \
# 0                 30                  30                  30
#
#    entertainment_time(h)  time_per_slot(mins)
# 0                     60                175.0

# %%
daily_time = time_tracker.topics()

# %%
daily_time.alltopics()
# Out:
#         main_topics       sub_topics
# 0   web_development         html_css
# 1   web_development       javascript
# 2   web_development            react
# 3      web_scraping         selenium
# 4      web_scraping           scrapy
# 5      web_scraping            BSoup
# 6    web_frameworks            flask
# 7    web_frameworks           django
# 8    web_frameworks          fastapi
# 9         databases            mysql
# 10              eda           pandas
# 11              eda       matplotlib
# 12              eda          seaborn
# 13  python_projects              eda
# 14  python_projects      webscraping
# 15  python_projects  web_development
# 16  python_projects   web_frameworks
# 17  python_projects           opencv

# %%
daily_time.add_date('05-06')
# Out:
# 05-06 is added

# %%
daily_time.select_topics(1,2,3)
# Out:
#        main_topics  sub_topics    05-06  time_slot_1_start  time_slot_1_end  \
# 1  web_development  javascript  CHOOSEN                NaN              NaN
# 2  web_development       react  CHOOSEN                NaN              NaN
# 3     web_scraping    selenium  CHOOSEN                NaN              NaN
#
#    time_slot_2_start  time_slot_2_end  time_slot_3_start  time_slot_3_end  \
# 1                NaN              NaN                NaN              NaN
# 2                NaN              NaN                NaN              NaN
# 3                NaN              NaN                NaN              NaN
#
#    time_slot_4_start  time_slot_4_end  time_slot_5_start  time_slot_5_end
# 1                NaN              NaN                NaN              NaN
# 2                NaN              NaN                NaN              NaN
# 3                NaN              NaN                NaN              NaN

# %%
daily_time.time_start(1,1)
# Out:
#        main_topics  sub_topics    05-06 time_slot_1_start  time_slot_1_end  \
# 1  web_development  javascript  CHOOSEN   20:10:10.254547              NaN
# 2  web_development       react  CHOOSEN               NaN              NaN
# 3     web_scraping    selenium  CHOOSEN               NaN              NaN
#
#    time_slot_2_start  time_slot_2_end  time_slot_3_start  time_slot_3_end  \
# 1                NaN              NaN                NaN              NaN
# 2                NaN              NaN                NaN              NaN
# 3                NaN              NaN                NaN              NaN
#
#    time_slot_4_start  time_slot_4_end  time_slot_5_start  time_slot_5_end
# 1                NaN              NaN                NaN              NaN
# 2                NaN              NaN                NaN              NaN
# 3                NaN              NaN                NaN              NaN

# %%
daily_time.end_time(1,1)
# Out:
#        main_topics  sub_topics    05-06 time_slot_1_start  time_slot_1_end  \
# 1  web_development  javascript  CHOOSEN   20:10:10.254547  20:10:10.734702
# 2  web_development       react  CHOOSEN               NaN              NaN
# 3     web_scraping    selenium  CHOOSEN               NaN              NaN
#
#    time_slot_2_start  time_slot_2_end  time_slot_3_start  time_slot_3_end  \
# 1                NaN              NaN                NaN              NaN
# 2                NaN              NaN                NaN              NaN
# 3                NaN              NaN                NaN              NaN
#
#    time_slot_4_start  time_slot_4_end  time_slot_5_start  time_slot_5_end
# 1                NaN              NaN                NaN              NaN
# 2                NaN              NaN                NaN              NaN
# 3                NaN              NaN                NaN              NaN

# %%
daily_time.table()
# Out:
# done
#        main_topics  sub_topics    05-06 time_slot_1_start  time_slot_1_end  \
# 0  web_development  javascript  CHOOSEN   20:10:10.254547  20:10:10.734702
# 1  web_development       react  CHOOSEN               NaN              NaN
# 2     web_scraping    selenium  CHOOSEN               NaN              NaN
#
#    time_slot_2_start  time_slot_2_end  time_slot_3_start  time_slot_3_end  \
# 0                NaN              NaN                NaN              NaN
# 1                NaN              NaN                NaN              NaN
# 2                NaN              NaN                NaN              NaN
#
#    time_slot_4_start  time_slot_4_end  time_slot_5_start  time_slot_5_end
# 0                NaN              NaN                NaN              NaN
# 1                NaN              NaN                NaN              NaN
# 2                NaN              NaN                NaN              NaN
